# %%
import dlib
import face_recognition as fr
from PIL import Image

# %%
# Normal face
image = fr.load_image_file("/Users/Colin/Google_Drive/Big_Data_DSGS_1004/wiki/00/10623500_1931-09-25_1956.jpg")
face_locations = fr.face_locations(image)

# %%
Image.fromarray(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x493 at 0x10F425E80>

# %%
# top, right, bottom, left
# change to left, top, right, bottom
face_location = face_locations[0]

# %%
top, right, bottom, left = face_location
face_image = image[top:bottom, left:right]
pil_image = Image.fromarray(face_image)
pil_image
# Out:
# <PIL.Image.Image image mode=RGB size=108x107 at 0x10FC89C88>

# %%
# Empty photo
image = fr.load_image_file("/Users/Colin/Google_Drive/Big_Data_DSGS_1004/wiki/00/1160300_1947-03-06_1983.jpg")
face_locations = fr.face_locations(image)
Image.fromarray(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1x1 at 0x10FC89A20>

# %%
face_locations
# Out:
# []

# %%
# Tough photo
image = fr.load_image_file("/Users/Colin/Google_Drive/Big_Data_DSGS_1004/wiki/00/3482000_1971-03-20_2005.jpg")
face_locations = fr.face_locations(image, number_of_times_to_upsample=2)
Image.fromarray(image)

# %%
face_locations

# %%
fr.face_locations?
